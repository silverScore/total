# %%
import pandas as pd
base_bath = 'C:/silverScore/projects/silverScore/care/data/'

# %%
rank_df = pd.read_csv(base_bath+'rankStatusData.csv', encoding='utf-8')
address_df = pd.read_csv(base_bath+'addressNumbers.csv', encoding='utf-8')
total_df = pd.DataFrame()

# %%
rank_df 
#ref :
# Out:
#        11156000018    서울특별시립 남부노인전문요양원      노인요양시설  2018년 정기평가  서울특별시  \
# 0      11156000023         구립영등포노인케어센터      노인요양시설  2018년 정기평가  서울특별시
# 1      11156000049      참노인요양원(공동생활가정)  노인요양공동생활가정  2018년 정기평가  서울특별시
# 2      11156000057     주현노인요양원(공동생활가정)  노인요양공동생활가정  2018년 정기평가  서울특별시
# 3      11156000213  21세기요양원 노인요양공동생활가정  노인요양공동생활가정  2018년 정기평가  서울특별시
# 4      11156000148               미래요양원  노인요양공동생활가정  2018년 정기평가  서울특별시
# ...            ...                 ...         ...         ...    ...
# 15522  34146000429          가정방문요양신갈센터        방문목욕  2021년 수시평가    경기도
# 15523  34146000435            누리노인복지센터        방문목욕  2021년 수시평가    경기도
# 15524  34146000577           연세주야간보호센터       주야간보호  2021년 수시평가    경기도
# 15525  24146000037       루터대학교용인노인복지센터       주야간보호  2021년 수시평가    경기도
# 15526  34146000659       해피데이 주·야간보호센터       주야간보호  2021년 수시평가    경기도
#
#           영등포구  2018-08-06  A  100  100.1  100.2  98   87
# 0         영등포구  2018-08-06  A   98     87    100  94   96
# ...
